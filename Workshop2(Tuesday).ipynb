# %% [markdown]
# <a href="https://colab.research.google.com/github/anurag-76/CM-Workshop2/blob/main/Workshop2(Tuesday).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WORKSHOP 2
# # Name - Anurag Patel
# # Uni ID - 2608976

# %% [markdown]
# 1. Write a Python function that takes a list and returns a new list with distinct elements from the first list.
# Sample List : [1,2,3,3,3,3,4,5] Unique List : [1, 2, 3, 4, 5]

# %%
def unique_elements(input_list):
    # Convert the list to a set to remove duplicates, then back to a list
    return list(set(input_list))

sample_list = [1, 2, 3, 3, 3, 3, 4, 5]
print(unique_elements(sample_list))

# %% [markdown]
# 2.	Write a Python function that takes a number as a parameter and checks whether the number is prime or not.

# %%
def check_prime():
    num = int(input("Enter any number: "))
    f = 0
    for i in range(1, num+1):
        if num % i == 0:
            f += 1

    if f == 2:
        print("The number is PRIME")
    else:
        print("The number is not PRIME")

check_prime()
# Out:
# Enter any number: 12
# The number is not PRIME

# %% [markdown]
# 3. Write a program to print twin primes less than 1000. If two consecutive odd numbers are
# both prime then they are known as twin primes.

# %%
# Function to check if a number is prime
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

# Print twin primes less than 1000
for i in range(3, 1000, 2):  # check only odd numbers
    if is_prime(i) and is_prime(i + 2):
        print(f"({i}, {i+2})")
# Out:
# (3, 5)
# (5, 7)
# (11, 13)
# (17, 19)
# (29, 31)
# (41, 43)
# (59, 61)
# (71, 73)
# (101, 103)
# (107, 109)
# (137, 139)
# (149, 151)
# (179, 181)
# (191, 193)
# (197, 199)
# (227, 229)
# (239, 241)
# (269, 271)
# (281, 283)
# (311, 313)
# (347, 349)
# (419, 421)
# (431, 433)
# (461, 463)
# (521, 523)
# (569, 571)
# (599, 601)
# (617, 619)
# (641, 643)
# (659, 661)
# (809, 811)
# (821, 823)
# (827, 829)
# (857, 859)
# (881, 883)

# %% [markdown]
# 4. positive integer is called a perfect number if it is equal to the sum of all of its divisors,
# including 1 but excluding the number itself. For example, 6 = 1 + 2 + 3. Write a
# function sumOfDivisors that takes a positive integer n and returns the sum of all its divisors
# (excluding n).

# %%
def sumOfDivisors(n):
    total = 0
    for i in range(1, n):   # exclude n itself
        if n % i == 0:
            total += i
    if (total == n):
        print("It is perfect number")
    else:
        print("It is not a perfect number")

sumOfDivisors(6)
sumOfDivisors(28)
sumOfDivisors(255)
# Out:
# It is perfect number
# It is perfect number
# It is not a perfect number

# %% [markdown]
# 5.The smallest perfect number is 6. Write a program that finds and prints out the next perfect number. Hint:
# You should be able your sumOfDiviors function from your solution to previous question.

# %%
def SumOfDivisors(n):
    total = 0
    for i in range(1, n):   # exclude n itself
        if n % i == 0:
            total += i
    return total

def NextPerfectNumber(start_num):
    num = start_num
    while True:
        if SumOfDivisors(num) == num:  #Check If num is perfect number
            return num
        num += 1

# The smallest perfect number is 6. We start checking from 7.
NextPerfect = NextPerfectNumber(7)
print(f"The next perfect number after 6 is: {NextPerfect}")

# %% [markdown]
# 6.Write the python program to find the mean median from the following list:
# Marks = [20, 30, 35, 55, 70, 80, 90] Do not use the library function if there is one.

# %%
# Below is given list according to question
Marks = [20, 30, 35, 55, 70, 80, 90]

#calculating Mean
def calc_mean(data):
  sum = 0
  for i in data:
    sum += i
  return (sum / len(data))

#calculating Median
def calc_median(data):
  count = len(data)           #calculates length of list
  data.sort()                 #arranges the elements inside the list in ascending order
  if(count % 2 == 1):         #Odd number of Elements
    return data[count // 2]
  else:                       #Even number of Elements
    m1 = data[(count // 2)-1]
    m2 = data[count // 2]
    return (m1 + m2) / 2    #average of two mid values

print("The Mean of the given list : ",calc_mean(Marks))
print("The Median of the given list : ",calc_median(Marks))
# Out:
# The Mean of the given list :  54.285714285714285
# The Median of the given list :  55

# %% [markdown]
# 7. Write a function that converts a decimal number to binary number.

# %% [markdown]
# 8. Write a function prodDigits() that inputs a number and returns the product of digits of that
# number.
